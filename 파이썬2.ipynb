# %% [markdown]
# <a href="https://colab.research.google.com/github/Baeyeonho/dusghWkd/blob/main/%ED%8C%8C%EC%9D%B4%EC%8D%AC2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-93f444c5-90f4-48ae-82c7-ae4d0a9efb6c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-93f444c5-90f4-48ae-82c7-ae4d0a9efb6c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Selfie_20220113_나는연호_002.jpg to Selfie_20220113_나는연호_002.jpg

# %%
import cv2
import matplotlib.pyplot as plt
import time
import numpy as np

img_basic = cv2.imread('Selfie_20220113_나는연호_002.jpg', cv2.IMREAD_COLOR)
plt.imshow(cv2.cvtColor(img_basic, cv2.COLOR_BGR2RGB))
plt.show()

img_basic = cv2.cvtColor(img_basic, cv2.COLOR_BGR2GRAY)
plt.imshow(cv2.cvtColor(img_basic, cv2.COLOR_GRAY2RGB))
plt.show()

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-5acaabcb-8915-42d6-af72-c52483a1c431" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5acaabcb-8915-42d6-af72-c52483a1c431">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Selfie_20220113_나는연호_002.jpg to Selfie_20220113_나는연호_002 (1).jpg

# %%
image = cv2.imread('Selfie_20220113_나는연호_002.jpg')

print(image.shape)
print(image.size)

px = image[100, 100]

print(px)

print(px[2])
# Out:
# (1080, 1920, 3)
# 6220800
# [42 62 50]
# 50

# %%
image = cv2.imread('Selfie_20220113_나는연호_002.jpg')

start_time = time.time()
for i in range(0, 100):
    for j in range(0, 100):
        image[i, j] = [255, 255, 255]
print("--- %s seconds ---" % (time.time() - start_time))

start_time = time.time()
image[0:100, 0:100] = [0, 0, 0]
print("--- %s seconds ---" % (time.time() - start_time))

plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.show()
# Out:
# --- 0.021733999252319336 seconds ---
# --- 0.0003726482391357422 seconds ---

# %%
image = cv2.imread('Selfie_20220113_나는연호_002.jpg')

roi = image[200:350, 50:200]

image[0:150, 0:150] = roi

plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.show()

# %%
image = cv2.imread('Selfie_20220113_나는연호_002.jpg')
image[:, :, 2] = 0

plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.show()

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-4d6bc5ca-4842-4caa-9661-aae525dbedbb" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4d6bc5ca-4842-4caa-9661-aae525dbedbb">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Selfie_20220113_나는연호_002.jpg to Selfie_20220113_나는연호_002 (2).jpg

# %%
image = cv2.imread('Selfie_20220113_나는연호_002.jpg')
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.show()

expand = cv2.resize(image, None, fx=2.0, fy=2.0, interpolation=cv2.INTER_CUBIC)
plt.imshow(cv2.cvtColor(expand, cv2.COLOR_BGR2RGB))
plt.show()

shrink = cv2.resize(image, None, fx=0.8, fy=0.8, interpolation=cv2.INTER_AREA)
plt.imshow(cv2.cvtColor(shrink, cv2.COLOR_BGR2RGB))
plt.show()

# %%
image = cv2.imread('Selfie_20220113_나는연호_002.jpg')

height, width = image.shape[:2]

M = np.float32([[1, 0, 50], [0, 1, 10]])
dst = cv2.warpAffine(image, M, (width, height))

plt.imshow(cv2.cvtColor(dst, cv2.COLOR_BGR2RGB))
plt.show()

# %%
image = cv2.imread('Selfie_20220113_나는연호_002.jpg')

height, width = image.shape[:2]

M = cv2.getRotationMatrix2D((width / 2, height / 2), 90, 0.5)
dst = cv2.warpAffine(image, M, (width, height))

plt.imshow(cv2.cvtColor(dst, cv2.COLOR_BGR2RGB))
plt.show()
